# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
group_labels = ['Gen Z', 'Millenial', 'Gen X', 'Boomer+']
groups = ['genZ', 'millenial', 'genX', 'boomer']

dfs_dict = {}
for g in groups:
    df = pd.read_csv('../prolific_results/'+g+'_pp_numeric.csv', index_col=False).iloc[2:].reset_index(drop=True)
    if (g == 'genZ'):
        df = df.iloc[5:].reset_index(drop=True)
    dfs_dict[g] = df

# %%
dfs_dict['genZ']
# Out:
#               StartDate              EndDate Status        IPAddress Progress  \
# 0   2024-10-09 13:35:35  2024-10-09 13:38:13      0   96.250.124.249      100
# 1   2024-10-09 13:39:27  2024-10-09 13:40:19      0   131.226.201.34      100
# 2   2024-10-09 13:40:08  2024-10-09 13:41:20      0   70.164.222.245      100
# 3   2024-10-09 13:40:53  2024-10-09 13:42:05      0   172.56.153.130      100
# 4   2024-10-09 13:44:53  2024-10-09 13:46:09      0    107.194.5.227      100
# 5   2024-10-09 13:47:59  2024-10-09 13:49:08      0    76.20.222.189      100
# 6   2024-10-09 13:47:32  2024-10-09 13:49:40      0     47.230.113.5      100
# 7   2024-10-09 13:48:55  2024-10-09 13:50:52      0   98.185.151.210      100
# 8   2024-10-09 13:48:54  2024-10-09 13:51:30      0   107.180.161.14      100
# 9   2024-10-09 13:50:30  2024-10-09 13:51:38      0     204.14.39.75      100
# 10  2024-10-09 13:53:29  2024-10-09 13:55:45      0   100.11.145.179      100
# 11  2024-10-09 13:56:23  2024-10-09 13:57:33      0   172.58.125.115      100
# 12  2024-10-09 13:55:21  2024-10-09 13:57:44      0     68.81.62.210      100
# 13  2024-10-09 13:54:05  2024-10-09 13:58:05      0    174.251.129.8      100
# 14  2024-10-09 13:57:44  2024-10-09 13:58:46      0   157.131.255.68      100
# 15  2024-10-09 13:57:59  2024-10-09 14:00:06      0     71.142.5.134      100
# 16  2024-10-09 13:59:35  2024-10-09 14:00:50      0    47.229.126.83      100
# 17  2024-10-09 13:57:19  2024-10-09 14:01:38      0      73.55.26.78      100
# 18  2024-10-09 14:00:56  2024-10-09 14:02:07      0     71.62.35.210      100
# 19  2024-10-09 13:59:07  2024-10-09 14:02:14      0    174.196.67.63      100
# 20  2024-10-09 14:01:26  2024-10-09 14:02:14      0     63.146.206.5      100
# 21  2024-10-09 14:01:18  2024-10-09 14:02:24      0    107.77.236.68      100
# 22  2024-10-09 14:01:53  2024-10-09 14:03:28      0  207.254.171.165      100
# 23  2024-10-09 14:03:22  2024-10-09 14:03:57      0   75.163.183.215      100
# 24  2024-10-09 14:02:59  2024-10-09 14:04:08      0     47.32.216.75      100
# 25  2024-10-09 14:03:35  2024-10-09 14:04:37      0    70.44.106.169      100
# 26  2024-10-09 14:03:56  2024-10-09 14:04:42      0   108.16.117.137      100
# 27  2024-10-09 14:02:41  2024-10-09 14:04:52      0   174.229.119.66      100
# 28  2024-10-09 14:02:56  2024-10-09 14:05:02      0     172.56.41.17      100
# 29  2024-10-09 14:03:11  2024-10-09 14:05:12      0    67.43.243.150      100
# 30  2024-10-09 14:04:12  2024-10-09 14:05:26      0    65.184.213.10      100
# 31  2024-10-09 14:04:56  2024-10-09 14:06:03      0     74.73.33.205      100
# 32  2024-10-09 14:04:53  2024-10-09 14:06:05      0      99.0.82.235      100
# 33  2024-10-09 14:05:25  2024-10-09 14:06:30      0    38.130.72.158      100
# 34  2024-10-09 13:59:24  2024-10-09 14:06:38      0   166.196.61.122      100
# 35  2024-10-09 14:05:35  2024-10-09 14:06:53      0   71.186.167.116      100
# 36  2024-10-09 14:05:59  2024-10-09 14:07:22      0    75.190.77.203      100
# 37  2024-10-09 14:05:48  2024-10-09 14:07:36      0    74.96.150.108      100
# 38  2024-10-09 14:06:40  2024-10-09 14:07:55      0   172.58.181.133      100
# 39  2024-10-09 14:05:05  2024-10-09 14:08:13      0     76.152.55.23      100
# 40  2024-10-09 14:07:12  2024-10-09 14:08:13      0     70.161.38.22      100
# 41  2024-10-09 14:07:22  2024-10-09 14:08:53      0     76.177.13.57      100
# 42  2024-10-09 14:08:12  2024-10-09 14:09:18      0   47.215.140.249      100
# 43  2024-10-09 14:07:53  2024-10-09 14:09:25      0   173.73.116.117      100
# 44  2024-10-09 14:08:01  2024-10-09 14:09:36      0    98.233.181.81      100
# 45  2024-10-09 14:08:28  2024-10-09 14:09:59      0   98.163.239.237      100
# 46  2024-10-09 14:08:10  2024-10-09 14:10:01      0    107.119.69.21      100
# 47  2024-10-09 14:08:08  2024-10-09 14:11:31      0    172.59.193.19      100
# 48  2024-10-09 14:05:46  2024-10-09 14:12:21      0    68.109.171.99      100
# 49  2024-10-09 14:12:29  2024-10-09 14:21:07      0    69.231.64.201      100
#
#    Duration (in seconds) Finished         RecordedDate         ResponseId  \
# 0                    157        1  2024-10-09 13:38:14  R_1iosfHGMrkqSd4R
# 1                     51        1  2024-10-09 13:40:20  R_6ElQRvoqQOZSowH
# 2                     72        1  2024-10-09 13:41:21  R_6KhBbwWbGjF3UDD
# 3                     72        1  2024-10-09 13:42:05  R_3fki2URdKs9MK9F
# 4                     75        1  2024-10-09 13:46:10  R_7pm4tEZJcoYS7IZ
# 5                     68        1  2024-10-09 13:49:08  R_7fqVM0BeFCLdeWF
# 6                    128        1  2024-10-09 13:49:41  R_1OcMyP9lijGZtAd
# 7                    116        1  2024-10-09 13:50:52  R_5r2hAyVc394A3EP
# 8                    155        1  2024-10-09 13:51:30  R_3hGdGCINA47eDjm
# 9                     67        1  2024-10-09 13:51:39  R_1Ug3BIJZe3mjXeV
# 10                   135        1  2024-10-09 13:55:45  R_5HtSyFgu9bFqHCv
# 11                    69        1  2024-10-09 13:57:33  R_54bDqaeWW21w4ws
# 12                   142        1  2024-10-09 13:57:44  R_5FKHE0SycnAqG2k
# 13                   239        1  2024-10-09 13:58:05  R_6U6l1IZ53izgG90
# 14                    61        1  2024-10-09 13:58:46  R_3UgVSbQnvwHJSng
# 15                   127        1  2024-10-09 14:00:06  R_1S0Ml2Rsc3MIHBV
# 16                    75        1  2024-10-09 14:00:51  R_3qDS9Uxb6Txb1Ir
# 17                   258        1  2024-10-09 14:01:39  R_646LmWzqkKCYweR
# 18                    70        1  2024-10-09 14:02:08  R_1TZVDEeUXKp5YWJ
# 19                   187        1  2024-10-09 14:02:15  R_11cGuqSqVJlSLau
# 20                    47        1  2024-10-09 14:02:15  R_7HnpkXsrSKL37N0
# 21                    65        1  2024-10-09 14:02:24  R_7BrBE6EBaAYCfSN
# 22                    94        1  2024-10-09 14:03:28  R_7D1Pczh7qhuIXjs
# 23                    35        1  2024-10-09 14:03:58  R_31AEhySEixcUI1f
# 24                    69        1  2024-10-09 14:04:08  R_5rUUcq8kN2J2ElV
# 25                    62        1  2024-10-09 14:04:38  R_6pbJA7cQfG2FI6l
# 26                    46        1  2024-10-09 14:04:43  R_6eyX7vHSDJom6v7
# 27                   130        1  2024-10-09 14:04:52  R_1GBa7hmyqo89Il8
# 28                   126        1  2024-10-09 14:05:02  R_5QnwhvcPlgNzlpO
# 29                   121        1  2024-10-09 14:05:13  R_1fl4MZIrYUf0dT4
# 30                    73        1  2024-10-09 14:05:26  R_7eJKfkOgcff7ier
# 31                    67        1  2024-10-09 14:06:04  R_3tJ4FBMQgMkwvAq
# 32                    72        1  2024-10-09 14:06:06  R_7UCdd1eznkBZhFT
# 33                    65        1  2024-10-09 14:06:31  R_305Lvk7JhBzOAvf
# 34                   434        1  2024-10-09 14:06:39  R_5tKNjzYQ25YOUUh
# 35                    77        1  2024-10-09 14:06:53  R_5vWinay4QFkmxQ5
# 36                    83        1  2024-10-09 14:07:23  R_5wzwTWSPDOJsjxH
# 37                   107        1  2024-10-09 14:07:37  R_3BrhBoOnUEkkHvD
# 38                    75        1  2024-10-09 14:07:56  R_6zOzYWPDG5mynqK
# 39                   187        1  2024-10-09 14:08:13  R_620gecAhrQkVEfn
# 40                    61        1  2024-10-09 14:08:13  R_34tqbLmMN9z5KMh
# 41                    91        1  2024-10-09 14:08:53  R_6DG3oqrTDrp91QS
# 42                    65        1  2024-10-09 14:09:18  R_1rYrIoJPFIsfQoI
# 43                    91        1  2024-10-09 14:09:26  R_5n9LeJ8zbZgXVFu
# 44                    94        1  2024-10-09 14:09:36  R_7jZgogvt5FUx5RW
# 45                    91        1  2024-10-09 14:10:00  R_7Uf9mWmUCvvtFR9
# 46                   111        1  2024-10-09 14:10:01  R_3kGqgIuyCdx670u
# 47                   203        1  2024-10-09 14:11:32  R_1eotzorcJu5NowF
# 48                   395        1  2024-10-09 14:12:22  R_1GqQCEjT0wxDiMB
# 49                   518        1  2024-10-09 14:21:08  R_7LjHZGioPKc5fSX
#
#    RecipientLastName  ...                        Q0     Q1 Q6 Q7 Q2 Q3 Q4 Q5  \
# 0                NaN  ...  63ea85807f12578a26e26cff    1,3  2  2  1  2  2  1
# 1                NaN  ...  6679ecc3908c73c45a2b33c7  1,2,3  1  1  1  1  1  1
# 2                NaN  ...  657cd25c2339b131aac9e3cc    1,3  1  2  1  1  1  3
# 3                NaN  ...  61692a71630be6d801e55db0  1,2,3  1  1  1  1  1  1
# 4                NaN  ...  65dd20fc1eb656fe97f92e73  1,2,3  2  1  2  3  3  3
# 5                NaN  ...  655faafc7c71bdbb2bed6993    1,3  1  1  1  1  1  3
# 6                NaN  ...  655f9aa6a6e6b075c313823c    1,3  1  2  1  3  1  3
# 7                NaN  ...  66799712579fc86b5a2409df    1,3  2  1  3  1  1  3
# 8                NaN  ...  669e35893cd8da225b460f73  1,2,3  2  1  1  1  3  3
# 9                NaN  ...  60fcd520c811e3e35980e962    1,3  1  1  1  1  1  3
# 10               NaN  ...  61005d2a07743d7e63d2a81f  1,2,3  1  2  1  1  1  3
# 11               NaN  ...  610c3fd3bc5c413b87a3d7ce    1,3  1  1  1  1  1  3
# 12               NaN  ...  66e46bfe1f78048b57ab10ba      1  1  1  1  1  1  1
# 13               NaN  ...  66e4d9b28591c9a0b3438053    1,3  1  2  1  1  1  3
# 14               NaN  ...  6615af8e78ae7fb06612b199    1,3  2  1  2  1  3  3
# 15               NaN  ...  62029b56ef1cb18a1337c806    1,3  2  2  2  1  1  3
# 16               NaN  ...  65cbd1d82ab8a232e2e37546    1,3  1  2  1  1  3  3
# 17               NaN  ...  5c11d4c31f6f15000148d741  1,2,3  2  1  1  3  3  3
# 18               NaN  ...  662194a74abe1d4476f358ab      1  1  1  1  2  1  2
# 19               NaN  ...  67023a811f98e3d5c19686d0      1  1  1  1  3  1  1
# 20               NaN  ...  5995fcbe004c4f0001cc8626      1  1  1  1  1  1  1
# 21               NaN  ...  6111f586fe99b25bb899861a    1,2  1  1  1  1  1  1
# 22               NaN  ...  610814cc054d91bab7257c80  1,2,3  1  2  1  1  1  3
# 23               NaN  ...  65cb58d0b074d6157dc0a15d      1  1  1  1  1  1  1
# 24               NaN  ...  66bd6efe7c0ffd37f2ff2d3a      1  1  1  1  1  1  1
# 25               NaN  ...  5c8faafcbeca9900012bbf4f  1,2,3  1  1  1  1  1  1
# 26               NaN  ...  5e6af995a2b73d0bf367a519    1,3  1  1  1  1  1  1
# 27               NaN  ...  661aa17ad7ad8f4657e59dcd    1,3  2  1  1  2  1  3
# 28               NaN  ...  5ed57bda0af83d0fc18bbff7      1  1  1  1  1  1  1
# 29               NaN  ...  5e21cba92d38754b6cbddf6d    1,3  2  1  3  1  1  3
# 30               NaN  ...  5dc61266dbf82047e9a63610  1,2,3  1  1  2  1  3  3
# 31               NaN  ...  628bdbc77a9dddcd7f4ed538  1,2,3  1  2  1  2  1  3
# 32               NaN  ...  6503ad4977ac98e48eaf385f      1  1  1  1  1  3  3
# 33               NaN  ...  5e8d4e09cb3dc612a24b3ffc  1,2,3  1  2  2  1  1  2
# 34               NaN  ...  6706e43dd981a39f16cea057    1,3  2  2  1  2  3  2
# 35               NaN  ...  5f9c7e5d71894b1356ebaccf      1  1  1  1  1  1  1
# 36               NaN  ...  60e3cb01a5a92b6e1fc43ed5    1,3  1  2  3  3  1  3
# 37               NaN  ...  6078f6d6268363e5ccd98849  1,2,3  1  2  2  3  2  3
# 38               NaN  ...  655f8b6cb4482d62ae248259    1,3  2  1  3  1  3  3
# 39               NaN  ...  63e57af0f73c3e6a3e10bebd    1,3  1  2  1  3  1  1
# 40               NaN  ...  65cbdeafd1d03c67a4d77b2c    1,3  1  2  1  3  1  3
# 41               NaN  ...  5f93190131a30e0ac3456eaa  1,2,3  2  2  1  3  1  3
# 42               NaN  ...  60ab6e743bb39383d6ef9922    1,3  1  1  1  1  1  3
# 43               NaN  ...  61741ba984f258d5c6a1303c    1,3  1  1  1  1  1  1
# 44               NaN  ...  654b931ba4e1538bb3817430    1,3  2  1  1  3  1  3
# 45               NaN  ...  667447e858816e268d6a6759    1,3  1  1  1  3  3  3
# 46               NaN  ...  616326a20970334859e5230d      1  2  2  1  3  1  3
# 47               NaN  ...  5955a3eb98c9c400019f5c5f      1  1  1  1  1  1  1
# 48               NaN  ...  63d02e1aad0bc2a7bff2f925  1,2,3  1  2  1  2  1  1
# 49               NaN  ...  657f0f3e8efab1fba4ec5aac    1,3  2  1  1  1  1  3
#
#              Q8         Q9
# 0       1,2,3,6        5,7
# 1         1,3,6      2,5,7
# 2         1,3,6      2,5,7
# 3       1,2,3,6        5,7
# 4         2,5,7      2,5,7
# 5         1,3,6          7
# 6         2,6,7      2,5,7
# 7         1,2,7    1,2,6,7
# 8         3,6,7        1,2
# 9     1,2,3,6,7      2,5,7
# 10        1,3,6        2,7
# 11        1,2,3          7
# 12      1,2,3,6          5
# 13        1,6,7      1,2,7
# 14          3,6      2,5,7
# 15  1,2,3,5,6,7      2,6,7
# 16        1,3,6          2
# 17        2,3,6      1,2,7
# 18          1,3    2,5,6,7
# 19          2,6        5,7
# 20            1          5
# 21        1,3,6          5
# 22        1,3,7        2,5
# 23            3          7
# 24    1,2,3,6,7          5
# 25      1,3,6,7        2,5
# 26      1,2,3,7          5
# 27          2,6      2,6,7
# 28      1,2,3,6          5
# 29        3,6,7    1,2,5,7
# 30      1,3,6,7          2
# 31        1,3,6        2,7
# 32        1,3,6          2
# 33          5,7        5,7
# 34    1,2,5,6,7    1,2,3,7
# 35          3,6        2,7
# 36            3  1,2,3,5,7
# 37          1,6      2,5,7
# 38      1,2,3,6      2,5,7
# 39          3,6        2,5
# 40          3,6        2,5
# 41        3,5,7    1,2,3,5
# 42        1,3,6        2,7
# 43        2,3,6        5,7
# 44        1,2,7  1,2,3,5,6
# 45      1,2,5,6      3,5,6
# 46          3,6          7
# 47      1,2,3,6          5
# 48      1,2,3,6        5,7
# 49    1,2,3,6,7  1,2,3,5,7
#
# [50 rows x 27 columns]

# %%
# plot Q1

demo = 'genZ'
all_answer_frequencies = []
all_answer_frequencies_se = []
for demo in groups:
    # for one demographic
    df = dfs_dict[demo]
    df['Q1_ls'] = '[' + df['Q1'].astype(str)+']'
    df['Q1_ls'] = df['Q1_ls'].apply(eval)
    answer_frequencies = []
    answer_frequencies_se = []
    for answer in [1,2,3]:
        answer_count = np.sum(df['Q1_ls'].apply(lambda x: answer in x))
        answer_frequencies.append(answer_count)
        p = answer_count/len(df['Q1_ls'])
        se = 1.96*np.sqrt(p*(1-p))/np.sqrt(len(df['Q1_ls']))
        answer_frequencies_se.append(se)
    answer_frequencies = np.array(answer_frequencies)/50
    all_answer_frequencies.append(answer_frequencies)
    all_answer_frequencies_se.append(answer_frequencies_se)

# Example data
metrics = ['Search Engines', 'Generative\nSearch Engines', 'Chatbots\nwithout Citation']
demographics = group_labels
values = np.array(all_answer_frequencies)

# Bar width and positioning
bar_width = 0.2
x = np.arange(len(metrics))

# Create the plot
fig, ax = plt.subplots()

# Plot bars for each demographic
for i, demo in enumerate(demographics):
    ax.bar(x + i * bar_width, values[i], width=bar_width, label=demo, yerr=all_answer_frequencies_se[i])

# Customize the x-axis
ax.set_xticks(x + bar_width * 1.5)
ax.set_xticklabels(metrics)

# Add legend, labels, and title
ax.legend(title="Demographics")
ax.set_ylabel('Proportion of Respondents\nwho have used the platform category')
ax.set_xlabel('Platform category')
ax.set_title('Platform Use by Generation')

# Display the plot
plt.show()
print(all_answer_frequencies_se)
# Out:
# [[0.0, 0.12702251768879405, 0.11838140394504537], [0.0, 0.13130537231964273, 0.12445614167247833], [0.0, 0.11482321716447418, 0.13759144159430844], [0.0, 0.11087434329005065, 0.1381487198637758]]

# %%
# plot Q2
q_num = '6'
answer_choices = [1,2]
demographics = ['Gen Z','Millenial','Gen X','Boomer+']
metrics = ['high-stakes', 'low-stakes']
question = 'If you are seeking information that will influence your\ndecision-making in a ________ setting, which platform\nwould you rather use to find the information?'

all_answer_frequencies = []
all_answer_frequencies_se = []
for demo in groups:
    # for one demographic
    df = dfs_dict[demo]

    exposed_df = df[df['Q1_ls'].apply(lambda x: (1 in x) and (3 in x))]
    num_answered_se_6 = len(exposed_df[exposed_df['Q6']=='2'])
    num_answered_se_7 = len(exposed_df[exposed_df['Q7']=='2'])
    all_answer_frequencies.append([num_answered_se_6/len(exposed_df), num_answered_se_7/len(exposed_df)])

    p6 = num_answered_se_6/len(exposed_df)
    p7 = num_answered_se_7/len(exposed_df)
    se6 = 1.96*np.sqrt(p6*(1-p6))/np.sqrt(len(exposed_df))
    se7 = 1.96*np.sqrt(p7*(1-p7))/np.sqrt(len(exposed_df))

    all_answer_frequencies_se.append([se6, se7])

demographics = group_labels
values = np.array(all_answer_frequencies).T
all_answer_frequencies_se = np.array(all_answer_frequencies_se).T
# Bar width and positioning
x = np.arange(len(demographics))
bar_width = .34

# Create the plot
fig, ax = plt.subplots()

# Plot bars for each demographic
for i, met in enumerate(metrics):
    ax.bar(x + i * bar_width, values[i], width=bar_width, label=met, yerr=all_answer_frequencies_se[i])

# Customize the x-axis
ax.set_xticks(x+bar_width/2)
ax.set_xticklabels(demographics)

# Add legend, labels, and title
ax.set_ylabel('Proportion of Respondents\nwho prefer chatbots over search engines')
ax.set_xlabel('Demographic')
ax.set_title(question)
ax.legend(title="Setting")
plt.ylim(0,.65)
# Display the plot
plt.show()
all_answer_frequencies
# Out:
# [[0.3684210526315789, 0.4473684210526316],
#  [0.25, 0.3333333333333333],
#  [0.25, 0.2857142857142857],
#  [0.30434782608695654, 0.21739130434782608]]

# %%
# plot Q6 aggregate across all demographics
answer_choices = [1, 2]
metrics = ['high-stakes', 'low-stakes']
question = 'If you are seeking information that will influence your\ndecision-making in a ________ setting, which platform\nwould you rather use to find the information?'

# Initialize variables for aggregated counts
total_exposed = 0
total_num_answered_se_6 = 0
total_num_answered_se_7 = 0
vec6_aggregate = []
vec7_aggregate = []

# Aggregate the data across all demographics
for demo in groups:
    df = dfs_dict[demo]

    exposed_df = df[df['Q1_ls'].apply(lambda x: (1 in x) and (3 in x))]
    num_answered_se_6 = len(exposed_df[exposed_df['Q6'] == '2'])
    num_answered_se_7 = len(exposed_df[exposed_df['Q7'] == '2'])
    
    total_exposed += len(exposed_df)
    total_num_answered_se_6 += num_answered_se_6
    total_num_answered_se_7 += num_answered_se_7

# Calculate the proportions
prop_se_6 = total_num_answered_se_6 / total_exposed
prop_se_7 = total_num_answered_se_7 / total_exposed

se6_aggregate = 1.96 * np.sqrt(prop_se_6*(1-prop_se_6)/total_exposed)
se7_aggregate = 1.96 * np.sqrt(prop_se_7*(1-prop_se_7)/total_exposed)

# Prepare data for the plot
values_aggregate = [prop_se_6, prop_se_7]
se_aggregate = [se6_aggregate, se7_aggregate]

# Create the plot
fig, ax = plt.subplots()

# Bar width and positioning
x = np.arange(len(metrics))  # Two bars for high-stakes and low-stakes

# Plot bars for aggregate data
ax.bar(x, values_aggregate, yerr=se_aggregate, label="Aggregated")

# Customize the x-axis
ax.set_xticks(x)
ax.set_xticklabels(metrics)

# Add legend, labels, and title
ax.set_ylabel('Proportion of Respondents\nwho prefer chatbots over search engines')
ax.set_xlabel('Setting')
ax.set_title(question)

# Display the plot
plt.ylim(0,.65)
plt.show()

# %%
# plot Q2 by demographic
q_num = '5' # 2-5
answer_choices = [1,2,3]
metrics = ['Search Engine', 'Generative Search Engine', 'Chatbot']

questions = {'2':'If you have a question concerning how to handle a personal medical issue,\nwhich platform would you use to seek an answer?',
            '3':'If you have a question concerning topics in a friendly game of trivia,\nwhich platform would you use to seek an answer?',
             '4':'If you had a question concerning how to file your taxes,\nwhich platform would you use to seek an answer?',
             '5':'If you were trying to explain a complicated science topic to your third grade niece,\nwhich platform would you use to seek an answer?',
            }
question = questions[q_num]
all_answer_frequencies = []
all_answer_frequencies_se = []
for demo in groups:
    # for one demographic
    df = dfs_dict[demo]
    exposed_df = df
    exposed_df = df[df['Q1_ls'].apply(lambda x: (1 in x) and (3 in x))]
    num_answered_1 = len(exposed_df[exposed_df['Q'+q_num]=='1'])
    num_answered_2 = len(exposed_df[exposed_df['Q'+q_num]=='2'])
    num_answered_3 = len(exposed_df[exposed_df['Q'+q_num]=='3'])
    all_answer_frequencies.append([num_answered_1/len(exposed_df), num_answered_2/len(exposed_df), num_answered_3/len(exposed_df)])

    p1 = num_answered_1 / len(exposed_df)
    p2 = num_answered_2 / len(exposed_df)
    p3 = num_answered_3 / len(exposed_df)
    se1 = 1.96*np.sqrt(p1*(1-p1))/np.sqrt(len(exposed_df))
    se2 = 1.96*np.sqrt(p2*(1-p2))/np.sqrt(len(exposed_df))
    se3 = 1.96*np.sqrt(p3*(1-p3))/np.sqrt(len(exposed_df))

    all_answer_frequencies_se.append([se1, se2, se3])

# Example data

demographics = group_labels
values = np.array(all_answer_frequencies).T
all_answer_frequencies_se = np.array(all_answer_frequencies_se).T
# Bar width and positioning
x = np.arange(len(demographics))
bar_width = .3

# Create the plot
fig, ax = plt.subplots()

# Plot bars for each demographic
for i, met in enumerate(metrics):
    ax.bar(x + i * bar_width, values[i], width=bar_width, label=met, yerr=all_answer_frequencies_se[i])

# Customize the x-axis
ax.set_xticks(x+bar_width/2)
ax.set_xticklabels(demographics)

# Add legend, labels, and title
ax.set_ylabel('Proportion of Respondents\nwho prefer the specified platform')
ax.set_xlabel('Demographic')
ax.set_title(question)
ax.legend(title="Setting")
plt.ylim(0,1)
# Display the plot
plt.show()

# %%
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(nrows=2, ncols=2, figsize=(6, 8))
fig.set_size_inches([6,5])
ax_ls = {'2': ax1, '4':ax2, '3':ax3, '5':ax4}
# plot Q2-Q5 in aggregate across demographics

#___________ , which platform would you use to seek an answer?
for q_num in ['2', '3', '4', '5']:
    ax = ax_ls[q_num]
    # metrics = ['Search Engine', 'Generative Search Engine', 'Chatbot']
    metrics = ['Search Engine', 'LLM']
    
    questions = {'2':'If you have a question concerning how\nto handle a personal medical issue...',
                '3':'If you have a question concerning \ntopics in a friendly game of trivia...',
                 '4':'If you had a question concerning \nhow to file your taxes',
                 '5':'If you were trying to explain a complicated\nscience topic to your third grade niece...',
                }

    questions = {'2':'(A) Personal medical issue',
                '3':'(C) Trivia topics',
                 '4':'(B) Filing your taxes',
                 '5':'(D) Complicated science\nfor a third grader',
                }
    question = questions[q_num]
    all_answer_frequencies = []
    all_answer_frequencies_se = []
    num_answered_1 = 0
    num_answered_2 = 0
    num_answered_3 = 0
    total_exposed = 0
    vec1 = []
    vec2 = []
    vec3 = []
    for demo in groups:
        # for one demographic
        df = dfs_dict[demo]
        exposed_df = df
        exposed_df = df[df['Q1_ls'].apply(lambda x: (1 in x) and (3 in x))]
        num_answered_1 += len(exposed_df[exposed_df['Q'+q_num]=='1'])
        num_answered_2 += len(exposed_df[exposed_df['Q'+q_num]=='2'])
        num_answered_3 += len(exposed_df[exposed_df['Q'+q_num]=='3'])
        total_exposed += len(exposed_df[exposed_df['Q'+q_num]!='2']) # number of exposed participants who answered chatbots or search engines
    
    all_answer_frequencies.append([num_answered_1/total_exposed, num_answered_3/total_exposed])
    
    p1 = num_answered_1 / total_exposed
    p2 = num_answered_2 / total_exposed
    p3 = num_answered_3 / total_exposed
    se1 = 1.96*np.sqrt(p1*(1-p1))/np.sqrt(total_exposed)
    se2 = 1.96*np.sqrt(p2*(1-p2))/np.sqrt(total_exposed)
    se3 = 1.96*np.sqrt(p3*(1-p3))/np.sqrt(total_exposed)
    all_answer_frequencies_se.append([se1, se3])
    
    demographics = group_labels
    values = np.array(all_answer_frequencies)
    all_answer_frequencies_se = np.array(all_answer_frequencies_se)
    # Bar width and positioning
    x = np.arange(len(metrics))
    bar_width = .3
    
    ax.bar(metrics, values[0], yerr=all_answer_frequencies_se[0], color=['tab:blue', 'tab:orange'])
    
    # Customize the x-axis
    ax.set_xticklabels(metrics, fontsize=11)
    ax.tick_params(axis='both', labelsize=10)
    ax.set_title(question)
    ax.set_ylim(0, 1)
    
    # Display the plot
plt.subplots_adjust(wspace=.4, hspace=0.5)   
plt.ylim(0,1)
plt.savefig('figures/prolific_platform_preferences_by_topic', bbox_inches='tight', dpi=400)
plt.show()
# Out:
# /var/folders/w_/zs4f9qhx30b50tppzwrnhx2c0000gn/T/ipykernel_66268/3525866811.py:63: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(metrics, fontsize=11)
# /var/folders/w_/zs4f9qhx30b50tppzwrnhx2c0000gn/T/ipykernel_66268/3525866811.py:63: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(metrics, fontsize=11)
# /var/folders/w_/zs4f9qhx30b50tppzwrnhx2c0000gn/T/ipykernel_66268/3525866811.py:63: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(metrics, fontsize=11)
# /var/folders/w_/zs4f9qhx30b50tppzwrnhx2c0000gn/T/ipykernel_66268/3525866811.py:63: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(metrics, fontsize=11)

# %%
# Visualize reasons for preferring search engines over chatbots, or vice versa
# plot Q2
answer_choices = [1,2]
demographics = ['Gen Z','Millenial','Gen X','Boomer+']
metrics = ['...search engines...', 
           '...LLMs...']
question = 'What are your reasons to use ___________ when\nseeking information to answer a query?'
reasons_x_labels = ['Reliability of\nprovided answers',
                   'Convenience of\nobtaining an answer',
                   'Knowing where the\nanswer comes from',
                   'Entertainment of the \nunderlying technology',
                   'Variety of sources\nmade available',
                   'Seeking a highly\npersonalized answer']

all_answer_frequencies = []
all_answer_frequencies_se = []

num_answered_8 = np.zeros(6)
num_answered_9 = np.zeros(6)
vecs_8 = [[] for _ in range(6)]
vecs_9 = [[] for _ in range(6)]
total_num = 0
for demo in groups:
    # for one demographic
    df = dfs_dict[demo]

    exposed_df = df[df['Q1_ls'].apply(lambda x: (1 in x) and (3 in x))]
    curr_num_answered_8 = []
    curr_num_answered_9 = []
    for i, answer_key in enumerate(['1','2','3','5','6','7']):
        curr_num_answered_8.append(len(exposed_df[exposed_df['Q8'].str.contains(answer_key)]))
        curr_num_answered_9.append(len(exposed_df[exposed_df['Q9'].str.contains(answer_key)]))
        vecs_8[i].extend([1]*curr_num_answered_8[-1]+[0]*(len(exposed_df) - curr_num_answered_8[-1]))
        vecs_9[i].extend([1]*curr_num_answered_9[-1]+[0]*(len(exposed_df) - curr_num_answered_9[-1]))
        
    num_answered_8 += np.array(curr_num_answered_8) # each entry is the number of people who selected that box
    num_answered_9 += np.array(curr_num_answered_9)
    total_num += len(exposed_df) # the total number of people who responded

ses8 = [1.96*np.sqrt(n/total_num * (1-n/total_num))/np.sqrt(total_num) for n in num_answered_8]
ses9 = [1.96*np.sqrt(n/total_num * (1-n/total_num))/np.sqrt(total_num) for n in num_answered_9]

# sort by blue bar height
sorted_indices = np.argsort(-num_answered_8)
num_answered_8 = np.array(num_answered_8)[sorted_indices]
num_answered_9 = np.array(num_answered_9)[sorted_indices]
ses8 = np.array(ses8)[sorted_indices]
ses9 = np.array(ses9)[sorted_indices]
reasons_x_labels = np.array(reasons_x_labels)[sorted_indices]
all_answer_frequencies = [num_answered_8/total_num, num_answered_9/total_num]
all_answer_frequencies_se = [ses8, ses9]
# Example data

demographics = group_labels
values = np.array(all_answer_frequencies)

# Bar width and positioning
x = np.arange(6)
bar_width = .34

# Create the plot
fig, ax = plt.subplots()
fig.set_size_inches(5,2)
# Plot bars for each demographic
for i, met in enumerate(metrics):
    ax.bar(x + i * bar_width, values[i], width=bar_width, label=met, yerr=all_answer_frequencies_se)

# Customize the x-axis
ax.set_xticks(x+bar_width/2)
ax.set_xticklabels(['']*6)

for i, label in enumerate(reasons_x_labels):
    plt.text(
        x[i],
        -0.15,  # x position is from data, y position is manual offset
        label,
        ha='left',   # Adjust alignment
        rotation=315,
        rotation_mode='anchor'
    )

plt.xticks(rotation=315, ha='left', va='top')

# Add legend, labels, and title
ax.set_ylabel('Proportion of Respondents\nwho include the reason')
ax.set_title(question, pad=14)
ax.legend(bbox_to_anchor=(1.01,1.026), labelspacing=.25, fontsize=9)
plt.ylim(0,1)


# Display the plot
plt.savefig('figures/prolific_platform_preference_reasons', bbox_inches='tight', dpi=400)

plt.show()
